# %%
import os
import zipfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
local_zip = "/content/drive/MyDrive/PCD/Indonesian Herb Leaf Dataset 3500.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall("/content/drive/MyDrive/Citra")
zip_ref.close()

# %%
# %cd /content/drive/MyDrive/Citra/Indonesian Herb Leaf Dataset 3500
# Out:
# /content/drive/MyDrive/Citra/Indonesian Herb Leaf Dataset 3500

# %%
import shutil
# !pip install split-folders
# %cd /content/drive/MyDrive/Citra
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# /content/drive/MyDrive/Citra

# %%
# !unzip \*.zip &> /dev/null && rm *.zip

# %%
# !mkdir "/content/drive/MyDrive/Citra/dataset_split"

# %%
import splitfolders  # library untuk membagi dataset ke train, val, test

# Lokasi folder dataset awal yang berisi semua gambar per kelas
input_folder = "/content/drive/MyDrive/Citra/Indonesian Herb Leaf Dataset 3500"

# Lokasi folder output setelah dataset di-split
output_folder = "/content/drive/MyDrive/Citra/dataset_split"

# Proses pembagian dataset
splitfolders.ratio(
    input_folder,              # folder asal
    output=output_folder,      # folder tujuan hasil split
    seed=1337,                  # seed untuk randomisasi agar hasil selalu sama
    ratio=(0.7, 0.2, 0.1),      # 70% train, 20% val, 10% test
    group_prefix=None           # biarkan None, jika dataset biasa (bukan paired data)
)

print("Proses split selesai! Dataset sudah dipisahkan ke dalam folder Train, Val, dan Test.")
# Out:
# Copying files: 3500 files [00:50, 69.95 files/s]
# Proses split selesai! Dataset sudah dipisahkan ke dalam folder Train, Val, dan Test.

# %%
base_dir = "/content/drive/MyDrive/Citra/dataset_split"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah Buaya","Kemangi","Jeruk Nipis","Jambu Biji","Belimbing Wuluh"] # ImageDataGenerator found 11 classes. Check the dataset folders to identify the extra class.

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah Buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk Nipis')
jambubiji_train_path = os.path.join(train_dir, 'Jambu Biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah Buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk Nipis')
jambubiji_val_path = os.path.join(val_dir, 'Jambu Biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))


print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk Nipis: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))


print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk Nipis: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2440
# Panjang validation: 700
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 244
# Panjang data train Peledri: 244
# Panjang data train Pepaya: 244
# Panjang data train Pandan: 244
# Panjang data train Nangka: 244
# Panjang data train Lidah Buaya: 244
# Panjang data train Kemangi: 244
# Panjang data train Jeruk Nipis: 244
# Panjang data train Jambu Biji: 244
# Panjang data train Belimbing Wuluh: 244
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 70
# Panjang data validation Peledri: 70
# Panjang data validation Pepaya: 70
# Panjang data validation Pandan: 70
# Panjang data validation Nangka: 70
# Panjang data validation Lidah Buaya: 70
# Panjang data validation Kemangi: 70
# Panjang data validation Jeruk Nipis: 70
# Panjang data validation Jambu Biji: 70
# Panjang data validation Belimbing Wuluh: 70

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih129.jpg', 'Sirih193.jpg', 'Sirih346.jpg', 'Sirih231.jpg', 'Sirih016.jpg', 'Sirih133.jpg', 'Sirih321.jpg', 'Sirih294.jpg', 'Sirih286.jpg', 'Sirih138.jpg']
# ['Seledri129.jpg', 'Seledri193.jpg', 'Seledri346.jpg', 'Seledri231.jpg', 'Seledri016.jpg', 'Seledri133.jpg', 'Seledri321.jpg', 'Seledri294.jpg', 'Seledri286.jpg', 'Seledri138.jpg']
# ['Pepaya129.jpg', 'Pepaya193.jpg', 'Pepaya346.jpg', 'Pepaya231.jpg', 'Pepaya016.jpg', 'Pepaya133.jpg', 'Pepaya321.jpg', 'Pepaya294.jpg', 'Pepaya286.jpg', 'Pepaya138.jpg']
# ['Pandan129.jpg', 'Pandan193.jpg', 'Pandan346.jpg', 'Pandan231.jpg', 'Pandan016.jpg', 'Pandan133.jpg', 'Pandan321.jpg', 'Pandan294.jpg', 'Pandan286.jpg', 'Pandan138.jpg']
# ['Nangka129.jpg', 'Nangka193.jpg', 'Nangka346.jpg', 'Nangka231.jpg', 'Nangka016.jpg', 'Nangka133.jpg', 'Nangka321.jpg', 'Nangka294.jpg', 'Nangka286.jpg', 'Nangka138.jpg']
# ['Lidah buaya129.jpg', 'Lidah buaya193.jpg', 'Lidah buaya346.jpg', 'Lidah buaya231.jpg', 'Lidah Buaya016.jpg', 'Lidah buaya133.jpg', 'Lidah buaya321.jpg', 'Lidah buaya294.jpg', 'Lidah buaya286.jpg', 'Lidah buaya138.jpg']
# ['Kemangi129.jpg', 'Kemangi193.jpg', 'Kemangi346.jpg', 'Kemangi231.jpg', 'Kemangi016.jpg', 'Kemangi133.jpg', 'Kemangi321.jpg', 'Kemangi294.jpg', 'Kemangi286.jpg', 'Kemangi138.jpg']
# ['Jeruk Nipis129.jpg', 'Jeruk Nipis193.jpg', 'Jeruk Nipis346.jpg', 'Jeruk Nipis231.jpg', 'Jeruk Nipis016.jpg', 'Jeruk Nipis133.jpg', 'Jeruk Nipis321.jpg', 'Jeruk Nipis294.jpg', 'Jeruk Nipis286.jpg', 'Jeruk Nipis138.jpg']
# ['Jambu biji129.jpg', 'Jambu biji193.jpg', 'Jambu biji346.jpg', 'Jambu biji231.jpg', 'Jambu Biji016.jpg', 'Jambu biji133.jpg', 'Jambu biji321.jpg', 'Jambu biji294.jpg', 'Jambu biji286.jpg', 'Jambu biji138.jpg']
# ['Belimbing Wuluh129.jpg', 'Belimbing Wuluh193.jpg', 'Belimbing Wuluh346.jpg', 'Belimbing Wuluh231.jpg', 'Belimbing Wuluh016.jpg', 'Belimbing Wuluh133.jpg', 'Belimbing Wuluh321.jpg', 'Belimbing Wuluh294.jpg', 'Belimbing Wuluh286.jpg', 'Belimbing Wuluh138.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_sirih_pix = [os.path.join(sirih_train_path, fname)
                  for fname in train_sirih_fnames[ pic_index-8:pic_index]
                 ]
next_seledri_pix = [os.path.join(seledri_train_path, fname)
                  for fname in train_seledri_fnames[ pic_index-8:pic_index]
                 ]
next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
                    for fname in train_pepaya_fnames[ pic_index-8:pic_index]
                  ]
next_pandan_pix = [os.path.join(pandan_train_path, fname)
                    for fname in train_pandan_fnames[ pic_index-8:pic_index]
                  ]
next_nangka_pix = [os.path.join(nangka_train_path, fname)
                    for fname in train_nangka_fnames[ pic_index-8:pic_index]
                  ]
next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
                    for fname in train_lidahbuaya_fnames[ pic_index-8:pic_index]
                  ]
next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
                    for fname in train_kemangi_fnames[ pic_index-8:pic_index]
                  ]
next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
                    for fname in train_jeruk_fnames[ pic_index-8:pic_index]
                  ]
next_jambubiji_pix = [os.path.join(jambubiji_train_path, fname)
                    for fname in train_jambubiji_fnames[ pic_index-8:pic_index]
                  ]
next_belimbingwuluh_pix = [os.path.join(belimbingwuluh_train_path, fname)
                    for fname in train_belimbingwuluh_fnames[ pic_index-8:pic_index]
                  ]

print(next_sirih_pix)

for i, img_path in enumerate(next_sirih_pix + next_seledri_pix + next_pepaya_pix + next_pandan_pix + next_nangka_pix + next_lidahbuaya_pix + next_kemangi_pix + next_jeruk_pix + next_jambubiji_pix + next_belimbingwuluh_pix):
  sp =  plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# ['/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih129.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih193.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih346.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih231.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih016.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih133.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih321.jpg', '/content/drive/MyDrive/Citra/dataset_split/train/Sirih/Sirih294.jpg']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.3,
    zoom_range = 0.3,
    rotation_range = 30,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest',
)
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle=True,
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)

test_datagen = ImageDataGenerator(
    rescale = 1./255,
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 2440 images belonging to 10 classes.
# Found 700 images belonging to 10 classes.
# Found 360 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout

# %%
image_size=[150,150]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# <KerasTensor shape=(None, 4, 4, 512), dtype=float32, sparse=False, ragged=False, name=keras_tensor_18>

# %%
x=Flatten()(vgg.output)
x=Dense(512, activation='relu')(x)
prediction=Dense(10,activation='softmax')(x)

# %%
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     4,194,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,914,634 (72.15 MB)
#  Trainable params: 18,914,634 (72.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=1,
      callbacks = [callbacks],
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 684ms/step - accuracy: 0.0866 - loss: 2.4562 - val_accuracy: 0.1750 - val_loss: 2.3314
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 458ms/step - accuracy: 0.2915 - loss: 2.0826 - val_accuracy: 0.3812 - val_loss: 1.9001
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 989ms/step - accuracy: 0.4820 - loss: 1.6472 - val_accuracy: 0.5125 - val_loss: 1.4445
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step - accuracy: 0.5556 - loss: 1.2815 - val_accuracy: 0.7188 - val_loss: 0.9634
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.5968 - loss: 1.0392 - val_accuracy: 0.8438 - val_loss: 0.5846
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 513ms/step - accuracy: 0.6963 - loss: 0.8687 - val_accuracy: 0.7750 - val_loss: 0.6678
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.7353 - loss: 0.7749 - val_accuracy: 0.6438 - val_loss: 1.0450
# Epoch 8/100
# 13/20 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7747 - loss: 0.6821
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 460ms/step - accuracy: 0.7627 - loss: 0.6881 - val_accuracy: 0.8625 - val_loss: 0.4222
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 424ms/step - accuracy: 0.8103 - loss: 0.5880 - val_accuracy: 0.7188 - val_loss: 0.8852
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 529ms/step - accuracy: 0.8271 - loss: 0.5244 - val_accuracy: 0.9312 - val_loss: 0.2646
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.7903 - loss: 0.6077 - val_accuracy: 0.8938 - val_loss: 0.3632
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 410ms/step - accuracy: 0.7281 - loss: 0.6788 - val_accuracy: 0.8313 - val_loss: 0.5425
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.8384 - loss: 0.4993 - val_accuracy: 0.8750 - val_loss: 0.4166
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 414ms/step - accuracy: 0.8559 - loss: 0.4257 - val_accuracy: 0.9438 - val_loss: 0.2211
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.8625 - loss: 0.4065 - val_accuracy: 0.9187 - val_loss: 0.2684
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.8645 - loss: 0.4146 - val_accuracy: 0.9312 - val_loss: 0.2472
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 381ms/step - accuracy: 0.8932 - loss: 0.3112 - val_accuracy: 0.8438 - val_loss: 0.4159
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 462ms/step - accuracy: 0.8555 - loss: 0.3829 - val_accuracy: 0.9500 - val_loss: 0.1642
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 353ms/step - accuracy: 0.8697 - loss: 0.3464 - val_accuracy: 0.9125 - val_loss: 0.2925
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.8627 - loss: 0.3895 - val_accuracy: 0.9563 - val_loss: 0.1594
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 322ms/step - accuracy: 0.8631 - loss: 0.3704 - val_accuracy: 0.9312 - val_loss: 0.2124
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.8845 - loss: 0.3477 - val_accuracy: 0.9187 - val_loss: 0.1919
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9262 - loss: 0.2454 - val_accuracy: 0.9500 - val_loss: 0.1304
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 256ms/step - accuracy: 0.8647 - loss: 0.3934 - val_accuracy: 0.9250 - val_loss: 0.2441
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.8631 - loss: 0.3807 - val_accuracy: 0.8687 - val_loss: 0.4350
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 417ms/step - accuracy: 0.8925 - loss: 0.3338 - val_accuracy: 0.8562 - val_loss: 0.4091
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 428ms/step - accuracy: 0.8860 - loss: 0.2822 - val_accuracy: 0.9438 - val_loss: 0.1968
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.9098 - loss: 0.2087 - val_accuracy: 0.9125 - val_loss: 0.2836
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step - accuracy: 0.9113 - loss: 0.2578 - val_accuracy: 0.9250 - val_loss: 0.2225
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9293 - loss: 0.2225 - val_accuracy: 0.9375 - val_loss: 0.2578
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 376ms/step - accuracy: 0.9151 - loss: 0.2490 - val_accuracy: 0.9187 - val_loss: 0.2495
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.9597 - loss: 0.1300 - val_accuracy: 0.8625 - val_loss: 0.3640
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 426ms/step - accuracy: 0.9062 - loss: 0.2590 - val_accuracy: 0.8750 - val_loss: 0.3673
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9176 - loss: 0.2255 - val_accuracy: 0.9812 - val_loss: 0.1521
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 406ms/step - accuracy: 0.9362 - loss: 0.2293 - val_accuracy: 0.9438 - val_loss: 0.2199
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.9334 - loss: 0.1889 - val_accuracy: 0.9563 - val_loss: 0.1548
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.9337 - loss: 0.1931 - val_accuracy: 0.9375 - val_loss: 0.1981
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9239 - loss: 0.2308 - val_accuracy: 0.9312 - val_loss: 0.2279
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.9107 - loss: 0.2823 - val_accuracy: 0.9125 - val_loss: 0.2740
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.9360 - loss: 0.2352 - val_accuracy: 0.9750 - val_loss: 0.0966
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 412ms/step - accuracy: 0.9142 - loss: 0.2195 - val_accuracy: 0.9563 - val_loss: 0.1382
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.9047 - loss: 0.3164 - val_accuracy: 0.9688 - val_loss: 0.1360
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 518ms/step - accuracy: 0.9491 - loss: 0.1993 - val_accuracy: 0.9750 - val_loss: 0.0908
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.9448 - loss: 0.1928 - val_accuracy: 0.8875 - val_loss: 0.3773
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.9165 - loss: 0.2173 - val_accuracy: 0.9000 - val_loss: 0.2757
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 348ms/step - accuracy: 0.9397 - loss: 0.1773 - val_accuracy: 0.9500 - val_loss: 0.1762
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.9487 - loss: 0.1693 - val_accuracy: 0.9375 - val_loss: 0.1553
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.9332 - loss: 0.2296 - val_accuracy: 0.9563 - val_loss: 0.1162
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 518ms/step - accuracy: 0.9384 - loss: 0.2528 - val_accuracy: 0.9625 - val_loss: 0.1384
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 423ms/step - accuracy: 0.9488 - loss: 0.1361 - val_accuracy: 0.9500 - val_loss: 0.1431
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.9485 - loss: 0.1530 - val_accuracy: 0.9812 - val_loss: 0.0867
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 407ms/step - accuracy: 0.9431 - loss: 0.1754 - val_accuracy: 0.9625 - val_loss: 0.1319
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 426ms/step - accuracy: 0.9155 - loss: 0.2372 - val_accuracy: 0.9625 - val_loss: 0.1199
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.9533 - loss: 0.1153 - val_accuracy: 0.9500 - val_loss: 0.1470
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.9734 - loss: 0.1313 - val_accuracy: 0.9750 - val_loss: 0.0933
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - accuracy: 0.9326 - loss: 0.1656 - val_accuracy: 0.9375 - val_loss: 0.2014
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9324 - loss: 0.1560 - val_accuracy: 0.9688 - val_loss: 0.0692
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 411ms/step - accuracy: 0.9494 - loss: 0.1651 - val_accuracy: 0.9688 - val_loss: 0.0987
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 536ms/step - accuracy: 0.9643 - loss: 0.1496 - val_accuracy: 0.9500 - val_loss: 0.1716
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 330ms/step - accuracy: 0.9616 - loss: 0.1351 - val_accuracy: 0.9688 - val_loss: 0.0905
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.9444 - loss: 0.1695 - val_accuracy: 0.9500 - val_loss: 0.1822
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.9433 - loss: 0.1508 - val_accuracy: 0.9812 - val_loss: 0.0737
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.9392 - loss: 0.1857 - val_accuracy: 0.9563 - val_loss: 0.1271
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.9554 - loss: 0.1811 - val_accuracy: 0.9500 - val_loss: 0.1357
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.9409 - loss: 0.1779 - val_accuracy: 0.9688 - val_loss: 0.0998
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.9749 - loss: 0.1086 - val_accuracy: 0.9688 - val_loss: 0.1087
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 434ms/step - accuracy: 0.9530 - loss: 0.1269 - val_accuracy: 0.9750 - val_loss: 0.0830
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 421ms/step - accuracy: 0.9454 - loss: 0.1497 - val_accuracy: 0.9812 - val_loss: 0.0929
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.9596 - loss: 0.1430 - val_accuracy: 0.9750 - val_loss: 0.1094
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9445 - loss: 0.0973 - val_accuracy: 0.9750 - val_loss: 0.0812
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 480ms/step - accuracy: 0.9406 - loss: 0.1359 - val_accuracy: 0.9750 - val_loss: 0.0829
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.9510 - loss: 0.1542 - val_accuracy: 0.9688 - val_loss: 0.0767
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 403ms/step - accuracy: 0.9868 - loss: 0.0637 - val_accuracy: 0.9625 - val_loss: 0.1233
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.9862 - loss: 0.0801 - val_accuracy: 0.9563 - val_loss: 0.1126
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 423ms/step - accuracy: 0.9597 - loss: 0.1227 - val_accuracy: 0.9375 - val_loss: 0.1539
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.9738 - loss: 0.0940 - val_accuracy: 0.9500 - val_loss: 0.1357
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.9732 - loss: 0.0989 - val_accuracy: 0.9563 - val_loss: 0.1329
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 497ms/step - accuracy: 0.9674 - loss: 0.1008 - val_accuracy: 0.9750 - val_loss: 0.0746
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.9765 - loss: 0.0726 - val_accuracy: 0.9812 - val_loss: 0.1066
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.9770 - loss: 0.0752 - val_accuracy: 0.9500 - val_loss: 0.1503
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 468ms/step - accuracy: 0.9744 - loss: 0.0920 - val_accuracy: 0.9438 - val_loss: 0.1313
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 414ms/step - accuracy: 0.9617 - loss: 0.1153 - val_accuracy: 0.9438 - val_loss: 0.1669
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.9565 - loss: 0.1101 - val_accuracy: 0.9625 - val_loss: 0.1069
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.9720 - loss: 0.1189 - val_accuracy: 0.9875 - val_loss: 0.0508
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 401ms/step - accuracy: 0.9605 - loss: 0.1072 - val_accuracy: 0.9812 - val_loss: 0.0486
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.9587 - loss: 0.0766 - val_accuracy: 0.9625 - val_loss: 0.1033
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 404ms/step - accuracy: 0.9779 - loss: 0.0647 - val_accuracy: 0.9563 - val_loss: 0.1102
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.9601 - loss: 0.1005 - val_accuracy: 0.9688 - val_loss: 0.0717
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 412ms/step - accuracy: 0.9512 - loss: 0.1176 - val_accuracy: 0.9250 - val_loss: 0.1410
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.9593 - loss: 0.1407 - val_accuracy: 0.9563 - val_loss: 0.1352
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 429ms/step - accuracy: 0.9724 - loss: 0.1230 - val_accuracy: 0.9563 - val_loss: 0.1397
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9637 - loss: 0.1077 - val_accuracy: 0.9625 - val_loss: 0.0889
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.9848 - loss: 0.0557 - val_accuracy: 0.9312 - val_loss: 0.2179
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.9664 - loss: 0.0999 - val_accuracy: 0.9750 - val_loss: 0.1221
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 409ms/step - accuracy: 0.9592 - loss: 0.1528 - val_accuracy: 0.9750 - val_loss: 0.0975
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.9478 - loss: 0.1123 - val_accuracy: 0.9688 - val_loss: 0.0756
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 415ms/step - accuracy: 0.9540 - loss: 0.1580 - val_accuracy: 0.9750 - val_loss: 0.0652
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 507ms/step - accuracy: 0.9791 - loss: 0.0769 - val_accuracy: 0.9375 - val_loss: 0.1879
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.9230 - loss: 0.1568 - val_accuracy: 0.9500 - val_loss: 0.1152
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 344ms/step - accuracy: 0.9619 - loss: 0.1199 - val_accuracy: 0.9563 - val_loss: 0.1050

# %%
model.save('/content/drive/MyDrive/Citra/Augmentasi_Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import load_model

model = load_model('/content/drive/MyDrive/Citra/Augmentasi_Model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

testLab = test_generator.classes
pred = model.predict(test_generator)
y_pred = np.argmax(pred, axis=-1)
class_names = test_generator.class_indices

print(classification_report(y_pred, testLab, target_names=class_names))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh       1.00      0.97      0.99        37
#      Jambu Biji       0.97      1.00      0.99        35
#     Jeruk Nipis       0.94      0.97      0.96        35
#         Kemangi       1.00      1.00      1.00        36
#     Lidah Buaya       1.00      1.00      1.00        36
#          Nangka       0.97      0.92      0.95        38
#          Pandan       1.00      1.00      1.00        36
#          Pepaya       0.97      1.00      0.99        35
#         Seledri       1.00      1.00      1.00        36
#           Sirih       1.00      1.00      1.00        36
#
#        accuracy                           0.99       360
#       macro avg       0.99      0.99      0.99       360
#    weighted avg       0.99      0.99      0.99       360

# %%
Cmatrix_test = confusion_matrix(testLab, y_pred)
plt.figure(figsize=(13,10))
ax = plt.subplot()
data = np.asarray(Cmatrix_test).reshape(10,10)
sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels', fontsize=14)
ax.set_ylabel('True labels', fontsize=14)
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Report', fontsize=18)
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
# from google.colab import files

path_test = '/content/drive/MyDrive/Citra/Indonesian Herb Leaf Dataset 3500/Pepaya/Pepaya001.jpg'

# uploaded = files.upload()

# for fn in uploaded.keys():
#   path = fn
img = image.load_img(path_test, target_size=(150,150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)

class_list = os.listdir(train_dir)

if classes[0][0]:
    prediction="Belimbing Wuluh"
elif classes[0][1]:
    prediction="Jambu Biji"
elif classes[0][2]:
    prediction="Jeruk"
elif classes[0][3]:
    prediction="Kemangi"
elif classes[0][4]:
    prediction="Lidah Buaya"
elif classes[0][5]:
    prediction="Nangka"
elif classes[0][6]:
    prediction="Pandan"
elif classes[0][7]:
    prediction="Pepaya"
elif classes[0][8]:
    prediction="Seledri"
elif classes[0][9]:
    prediction="Sirih"
else:
    prediction="[Undefined]"
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Pepaya
